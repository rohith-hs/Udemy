# %%
age=22

# %%
print(age)
# Out:
# 22

# %%
age=24
if age>22:
    print(age)
# Out:
# 24

# %%
if True:
    print(" this is printed")
    if False:
        print("this not  print")
    print("hello")
print("word")
print("1111")
print("2222")
# Out:
#  this is printed
# hello
# word
# 1111
# 2222

# %%
a=100

# %%
print(a)
# Out:
# 100

# %%
age=22
hight=6.8
name="rohi"
is_stuent=True

print("age=",age)
print("hight=",hight)
print("name=",name)
# Out:
# age= 22
# hight= 6.8
# name= rohi
